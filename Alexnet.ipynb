# %%
#Import libraries
import torch, torchvision
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import time
from torchvision.models import efficientnet_b0
#from torchsummary import summary

import numpy as np
import matplotlib.pyplot as plt
import osccccccc

from PIL import Image

# %%
image_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %%
dir="D:\Survallience Project"
dir
# Out:
# 'D:\\Survallience Project'

# %%
# Load the Data

# Set train and valid directory paths

dataset = "D:\Survallience Project"

train_directory = os.path.join(dataset, 'train')
valid_directory = os.path.join(dataset, 'valid')

# Batch size
bs = 32

# Number of classes
num_classes = len(os.listdir(valid_directory))  
print(num_classes)

# Load Data from folders
data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
    'valid': datasets.ImageFolder(root=valid_directory, transform=image_transforms['valid'])
}

# Get a mapping of the indices to the class names, in order to see the output classes of the test images.
idx_to_class = {v: k for k, v in data['train'].class_to_idx.items()}
print(idx_to_class)

# Size of Data, to be used for calculating Average Loss and Accuracy
train_data_size = len(data['train'])
valid_data_size = len(data['valid'])

# Create iterators for the Data loaded using DataLoader module
train_data_loader = DataLoader(data['train'], batch_size=bs, shuffle=True)
valid_data_loader = DataLoader(data['valid'], batch_size=bs, shuffle=True)
# Out:
# 2
# {0: 'fire', 1: 'human'}

# %%
train_data_size, valid_data_size
# Out:
# (1230, 1195)

# %%
alexnet = models.alexnet(pretrained=True)
alexnet
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
for param in alexnet.parameters():
    param.requires_grad = False

# %%
alexnet.classifier[6] = nn.Linear(4096, num_classes)
alexnet.classifier.add_module("7", nn.LogSoftmax(dim = 1))
alexnet
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %%
# Define Optimizer and Loss Function
loss_func = nn.NLLLoss()
optimizer = optim.Adam(alexnet.parameters())
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )

# %%
def train_and_validate(model, loss_criterion, optimizer, epochs=5):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(train_data_loader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(valid_data_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_valid_loss = valid_loss/valid_data_size 
        avg_valid_acc = valid_acc/valid_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch+1, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        #torch.save(model, dataset+'model'+str(epoch)+'.pt')
            
    return model, history

# %%
os.makedirs(dataset, exist_ok=True)

# Save the training history

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

num_epochs = 100
trained_model, history = train_and_validate(alexnet, loss_func, optimizer, num_epochs)

torch.save(history, os.path.join(dataset, '_history.pt'))
# Out:
# Epoch: 1/100
# Epoch : 001, Training: Loss: 0.0571, Accuracy: 97.5610%,
# 		Validation : Loss : 0.0076, Accuracy: 99.7490%, Time: 281.3580s
# Epoch: 2/100
# Epoch : 002, Training: Loss: 0.0117, Accuracy: 99.8374%,
# 		Validation : Loss : 0.0014, Accuracy: 100.0000%, Time: 117.0929s
# Epoch: 3/100
# Epoch : 003, Training: Loss: 0.0029, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0019, Accuracy: 100.0000%, Time: 98.1792s
# Epoch: 4/100
# Epoch : 004, Training: Loss: 0.0033, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0008, Accuracy: 100.0000%, Time: 103.9082s
# Epoch: 5/100
# Epoch : 005, Training: Loss: 0.0029, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0005, Accuracy: 100.0000%, Time: 104.5492s
# Epoch: 6/100
# Epoch : 006, Training: Loss: 0.0030, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0004, Accuracy: 100.0000%, Time: 105.2321s
# Epoch: 7/100
# Epoch : 007, Training: Loss: 0.0010, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0008, Accuracy: 100.0000%, Time: 105.0064s
# Epoch: 8/100
# Epoch : 008, Training: Loss: 0.0009, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0003, Accuracy: 100.0000%, Time: 104.7438s
# Epoch: 9/100
# Epoch : 009, Training: Loss: 0.0017, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0003, Accuracy: 100.0000%, Time: 104.9764s
# Epoch: 10/100
# Epoch : 010, Training: Loss: 0.0017, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0005, Accuracy: 100.0000%, Time: 105.8437s
# Epoch: 11/100
# Epoch : 011, Training: Loss: 0.0025, Accuracy: 99.8374%,
# 		Validation : Loss : 0.0006, Accuracy: 100.0000%, Time: 107.3627s
# Epoch: 12/100
# Epoch : 012, Training: Loss: 0.0018, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0003, Accuracy: 100.0000%, Time: 106.5515s
# Epoch: 13/100
# Epoch : 013, Training: Loss: 0.0005, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0003, Accuracy: 100.0000%, Time: 105.6587s
# Epoch: 14/100
# Epoch : 014, Training: Loss: 0.0005, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0002, Accuracy: 100.0000%, Time: 106.9631s
# Epoch: 15/100
# Epoch : 015, Training: Loss: 0.0005, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0002, Accuracy: 100.0000%, Time: 107.9147s
# Epoch: 16/100
# Epoch : 016, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.4214s
# Epoch: 17/100
# Epoch : 017, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 107.2651s
# Epoch: 18/100
# Epoch : 018, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.8443s
# Epoch: 19/100
# Epoch : 019, Training: Loss: 0.0004, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 107.3772s
# Epoch: 20/100
# Epoch : 020, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 107.1644s
# Epoch: 21/100
# Epoch : 021, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 107.3108s
# Epoch: 22/100
# Epoch : 022, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.2950s
# Epoch: 23/100
# Epoch : 023, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.2592s
# Epoch: 24/100
# Epoch : 024, Training: Loss: 0.0006, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.3600s
# Epoch: 25/100
# Epoch : 025, Training: Loss: 0.0006, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.2401s
# Epoch: 26/100
# Epoch : 026, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.2617s
# Epoch: 27/100
# Epoch : 027, Training: Loss: 0.0008, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 107.7633s
# Epoch: 28/100
# Epoch : 028, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 109.9518s
# Epoch: 29/100
# Epoch : 029, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.4901s
# Epoch: 30/100
# Epoch : 030, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 108.8747s
# Epoch: 31/100
# Epoch : 031, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 108.0413s
# Epoch: 32/100
# Epoch : 032, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.2832s
# Epoch: 33/100
# Epoch : 033, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.0025s
# Epoch: 34/100
# Epoch : 034, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.7954s
# Epoch: 35/100
# Epoch : 035, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.1155s
# Epoch: 36/100
# Epoch : 036, Training: Loss: 0.0005, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 108.3501s
# Epoch: 37/100
# Epoch : 037, Training: Loss: 0.0007, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.5981s
# Epoch: 38/100
# Epoch : 038, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.5449s
# Epoch: 39/100
# Epoch : 039, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.0842s
# Epoch: 40/100
# Epoch : 040, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.4985s
# Epoch: 41/100
# Epoch : 041, Training: Loss: 0.0031, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 107.1618s
# Epoch: 42/100
# Epoch : 042, Training: Loss: 0.0047, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0003, Accuracy: 100.0000%, Time: 106.8172s
# Epoch: 43/100
# Epoch : 043, Training: Loss: 0.0073, Accuracy: 99.7561%,
# 		Validation : Loss : 0.0002, Accuracy: 100.0000%, Time: 106.3584s
# Epoch: 44/100
# Epoch : 044, Training: Loss: 0.0006, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.5022s
# Epoch: 45/100
# Epoch : 045, Training: Loss: 0.0010, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.6121s
# Epoch: 46/100
# Epoch : 046, Training: Loss: 0.0026, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.4917s
# Epoch: 47/100
# Epoch : 047, Training: Loss: 0.0008, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.3018s
# Epoch: 48/100
# Epoch : 048, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.8345s
# Epoch: 49/100
# Epoch : 049, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.9757s
# Epoch: 50/100
# Epoch : 050, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 108.7183s
# Epoch: 51/100
# Epoch : 051, Training: Loss: 0.0005, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 108.3321s
# Epoch: 52/100
# Epoch : 052, Training: Loss: 0.0006, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.0521s
# Epoch: 53/100
# Epoch : 053, Training: Loss: 0.0006, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.3659s
# Epoch: 54/100
# Epoch : 054, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.3248s
# Epoch: 55/100
# Epoch : 055, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.8448s
# Epoch: 56/100
# Epoch : 056, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.4808s
# Epoch: 57/100
# Epoch : 057, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.3696s
# Epoch: 58/100
# Epoch : 058, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.7073s
# Epoch: 59/100
# Epoch : 059, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.3970s
# Epoch: 60/100
# Epoch : 060, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.5558s
# Epoch: 61/100
# Epoch : 061, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.0666s
# Epoch: 62/100
# Epoch : 062, Training: Loss: 0.0018, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.3520s
# Epoch: 63/100
# Epoch : 063, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.3956s
# Epoch: 64/100
# Epoch : 064, Training: Loss: 0.0024, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.2121s
# Epoch: 65/100
# Epoch : 065, Training: Loss: 0.0048, Accuracy: 99.8374%,
# 		Validation : Loss : 0.0005, Accuracy: 100.0000%, Time: 107.1998s
# Epoch: 66/100
# Epoch : 066, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0011, Accuracy: 99.9163%, Time: 105.6420s
# Epoch: 67/100
# Epoch : 067, Training: Loss: 0.0005, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 105.7282s
# Epoch: 68/100
# Epoch : 068, Training: Loss: 0.0007, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0003, Accuracy: 100.0000%, Time: 105.5389s
# Epoch: 69/100
# Epoch : 069, Training: Loss: 0.0026, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.8913s
# Epoch: 70/100
# Epoch : 070, Training: Loss: 0.0016, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0002, Accuracy: 100.0000%, Time: 107.3428s
# Epoch: 71/100
# Epoch : 071, Training: Loss: 0.0051, Accuracy: 99.7561%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.1456s
# Epoch: 72/100
# Epoch : 072, Training: Loss: 0.0003, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.3913s
# Epoch: 73/100
# Epoch : 073, Training: Loss: 0.0005, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 107.1477s
# Epoch: 74/100
# Epoch : 074, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.5361s
# Epoch: 75/100
# Epoch : 075, Training: Loss: 0.0012, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.4007s
# Epoch: 76/100
# Epoch : 076, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 107.0037s
# Epoch: 77/100
# Epoch : 077, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 106.5554s
# Epoch: 78/100
# Epoch : 078, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0001, Accuracy: 100.0000%, Time: 107.2230s
# Epoch: 79/100
# Epoch : 079, Training: Loss: 0.0029, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.3404s
# Epoch: 80/100
# Epoch : 080, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.8956s
# Epoch: 81/100
# Epoch : 081, Training: Loss: 0.0012, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.8429s
# Epoch: 82/100
# Epoch : 082, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.3735s
# Epoch: 83/100
# Epoch : 083, Training: Loss: 0.0002, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.0859s
# Epoch: 84/100
# Epoch : 084, Training: Loss: 0.0036, Accuracy: 99.8374%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.5123s
# Epoch: 85/100
# Epoch : 085, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.7807s
# Epoch: 86/100
# Epoch : 086, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.8931s
# Epoch: 87/100
# Epoch : 087, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.3452s
# Epoch: 88/100
# Epoch : 088, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.1845s
# Epoch: 89/100
# Epoch : 089, Training: Loss: 0.0024, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.4440s
# Epoch: 90/100
# Epoch : 090, Training: Loss: 0.0041, Accuracy: 99.9187%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.6581s
# Epoch: 91/100
# Epoch : 091, Training: Loss: 0.0006, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.5841s
# Epoch: 92/100
# Epoch : 092, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.7523s
# Epoch: 93/100
# Epoch : 093, Training: Loss: 0.0001, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.2704s
# Epoch: 94/100
# Epoch : 094, Training: Loss: 0.0018, Accuracy: 99.8374%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 108.6156s
# Epoch: 95/100
# Epoch : 095, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.0097s
# Epoch: 96/100
# Epoch : 096, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 106.9914s
# Epoch: 97/100
# Epoch : 097, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 107.8827s
# Epoch: 98/100
# Epoch : 098, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 130.6215s
# Epoch: 99/100
# Epoch : 099, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 115.7577s
# Epoch: 100/100
# Epoch : 100, Training: Loss: 0.0000, Accuracy: 100.0000%,
# 		Validation : Loss : 0.0000, Accuracy: 100.0000%, Time: 105.7114s

# %%
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.savefig(dataset+'_loss_curve.png')
plt.show()

# %%
plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0,1)
plt.savefig(dataset+'_accuracy_curve.png')
plt.show()

# %%
def predict(model, test_image_name):
    '''
    Function to predict the class of a single test image
    Parameters
        :param model: Model to test
        :param test_image_name: Test image

    '''
    
    transform = image_transforms['test']

    test_image = Image.open(test_image_name)
    plt.imshow(test_image)
    
    test_image_tensor = transform(test_image)

    if torch.cuda.is_available():
        test_image_tensor = test_image_tensor.view(1, 3, 224, 224).cuda()
    else:
        test_image_tensor = test_image_tensor.view(1, 3, 224, 224)
    
    with torch.no_grad():
        model.eval()
        # Model outputs log probabilities
        out = model(test_image_tensor)
        ps = torch.exp(out)
        topk, topclass = ps.topk(2, dim=1)
        for i in range(2):
            print("Predcition", i+1, ":", idx_to_class[topclass.numpy()[0][i]], ", Score: ", topk.numpy()[0][i])

# %%
# Out:
# Predcition 1 : fire , Score:  1.0
# Predcition 2 : human , Score:  1.4866028e-12

# %%
predict(trained_model,"D:\\Survallience Project\\valid\\human\\16.png")
# Out:
# Predcition 1 : human , Score:  1.0
# Predcition 2 : fire , Score:  2.8584854e-17
